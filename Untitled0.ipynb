# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchibagde-08/czca/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tesla Stock Price Exchange Using Facebook Prophet

# %%
  import pandas as pd
  import plotly.express as px
  from prophet import Prophet

# %%
import plotly.io as pio
pio.renderers.default='colab'

# %% [markdown]
# Importing the Datasets & Exploring it

# %%
 df= pd.read_csv('TSLA.csv')

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-06-05  217.800003  221.289993  214.520004  217.610001  217.610001
# 1    2023-06-06  216.139999  221.910004  212.529999  221.309998  221.309998
# 2    2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 3    2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 4    2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
# ..          ...         ...         ...         ...         ...         ...
# 248  2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 249  2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
# 250  2024-06-03  178.130005  182.639999  174.490005  176.289993  176.289993
# 251  2024-06-04  174.779999  177.759995  174.000000  174.770004  174.770004
# 252  2024-06-05  175.279999  176.149902  172.130005  174.960098  174.960098
#
#         Volume
# 0    151143100
# 1    146911600
# ...

# %%
df.nullvalue()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-9e33e0b04c8a> in <cell line: 1>()
# ----> 1 df.nullvalue()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'nullvalue'

# %%
df.info()

# %%
#df.describe() extremely useful for financial analysis as it gives statistical info
df.describe()

# %%
px.area(df,'Date','Close')

# %%
px.line(df,'Date','Close')

# %%
px.area(df,'Date','Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.bar(df,y='Volume')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.box(df,y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#facebook prophet is a forecasting tool

# %% [markdown]
# Data Preparation

# %%
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2023-06-05  217.800003  221.289993  214.520004  217.610001  217.610001
# 1    2023-06-06  216.139999  221.910004  212.529999  221.309998  221.309998
# 2    2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 3    2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 4    2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
# ..          ...         ...         ...         ...         ...         ...
# 248  2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 249  2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
# 250  2024-06-03  178.130005  182.639999  174.490005  176.289993  176.289993
# 251  2024-06-04  174.779999  177.759995  174.000000  174.770004  174.770004
# 252  2024-06-05  175.279999  176.149902  172.130005  174.960098  174.960098
#
#         Volume
# 0    151143100
# 1    146911600
# ...

# %%
column=['Date','Close']

# %%
column
# Out:
# ['Date', 'Close']

# %%
ndf=pd.DataFrame(df, columns= column)

# %%
ndf
# Out:
#            Date       Close
# 0    2023-06-05  217.610001
# 1    2023-06-06  221.309998
# 2    2023-06-07  224.570007
# 3    2023-06-08  234.860001
# 4    2023-06-09  244.399994
# ..          ...         ...
# 248  2024-05-30  178.789993
# 249  2024-05-31  178.080002
# 250  2024-06-03  176.289993
# 251  2024-06-04  174.770004
# 252  2024-06-05  174.960098
#
# [253 rows x 2 columns]

# %%
prophet_df=ndf.rename(columns={'Date':'ds', 'Close':'y'})

# %%
prophet_df
# Out:
#              ds           y
# 0    2023-06-05  217.610001
# 1    2023-06-06  221.309998
# 2    2023-06-07  224.570007
# 3    2023-06-08  234.860001
# 4    2023-06-09  244.399994
# ..          ...         ...
# 248  2024-05-30  178.789993
# 249  2024-05-31  178.080002
# 250  2024-06-03  176.289993
# 251  2024-06-04  174.770004
# 252  2024-06-05  174.960098
#
# [253 rows x 2 columns]

# %% [markdown]
# Creating Facebook Prophet Model

# %%
m=Prophet()
m.fit(prophet_df)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6ktv6eo9/eoqug7w4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp6ktv6eo9/oltq10s8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26396', 'data', 'file=/tmp/tmp6ktv6eo9/eoqug7w4.json', 'init=/tmp/tmp6ktv6eo9/oltq10s8.json', 'output', 'file=/tmp/tmp6ktv6eo9/prophet_modelqul4jfvi/prophet_model-20240605194325.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 19:43:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 19:43:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %% [markdown]
# Forcasting(predicting)

# %%
future=m.make_future_dataframe(periods=50)
forecast=m.predict(future)

# %%
forecast
# Out:
#             ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0   2023-06-05  255.480656  239.737673  282.811095   255.480656   255.480656
# 1   2023-06-06  255.336552  243.923432  285.660132   255.336552   255.336552
# 2   2023-06-07  255.192447  244.072971  283.565806   255.192447   255.192447
# 3   2023-06-08  255.048343  242.167309  282.991040   255.048343   255.048343
# 4   2023-06-09  254.904238  241.401804  281.991349   254.904238   254.904238
# ..         ...         ...         ...         ...          ...          ...
# 298 2024-07-21  147.538484  109.591934  148.485621   145.380656   150.080056
# 299 2024-07-22  147.332039  134.588768  175.576287   145.119240   149.932098
# 300 2024-07-23  147.125594  135.974703  178.409339   144.839987   149.794602
# 301 2024-07-24  146.919149  134.975549  175.310772   144.547891   149.642430
# 302 2024-07-25  146.712704  132.225720  173.032878   144.262346   149.544772
#
# ...

# %%
px.line(forecast, x='ds',y='yhat')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
  figure=m.plot(forecast,xlabel='ds',ylabel='y')

# %%
figure2=m.plot_components(forecast)

# %%
from google.colab import files
forecast.to_csv('forecast.csv')
files.download('forecast.csv')
